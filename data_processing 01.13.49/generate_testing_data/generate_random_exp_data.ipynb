# %%
import pandas as pd
import random
import string

# Function to generate random email
def generate_email():
    prefix = ''.join(random.choices(string.ascii_lowercase + string.digits, k=10))
    return f"{prefix}@gmail.com", prefix

# Function to generate random consent (0 or 1)
def generate_consent():
    return random.choice([0, 1])

# Function to generate random age (14-99)
def generate_age():
    return random.randint(14, 99)

# Function to generate random sex
def generate_sex():
    return random.choice(['Female', 'Male', 'Other/No Response'])

# Function to generate random ethnicity
def generate_ethnicity():
    return random.choice(['Hispanic/Latino', 'Not Hispanic/Latino', 'No Response'])

# Function to generate random race
def generate_race():
    return random.choice(['American Indian/Alaska Native', 'Asian', 'Native Hawaiian/Pacific Islander', 
                          'Black/African American', 'White/Caucasian', 'More than one race', 'No Response'])

# Function to generate random VVIQ responses (1-4)
def generate_vviq_responses():
    return [random.randint(1, 4) for _ in range(16)]

# Function to generate random ideal participation (0 or 1)
def generate_ideal_participation():
    return random.choice([0, 1])

# Function to generate random attention check task
def generate_attention_check_task():
    return random.choice(['Pictures', 'Abstract words', 'Concrete words', 'Numbers', 'Symbols'])

# Main function to generate the Parquet files
def generate_parquet_files(num_files):
    for _ in range(num_files):
        email, filename = generate_email()
        consent = generate_consent()
        age = generate_age()
        sex = generate_sex()
        ethnicity = generate_ethnicity()
        race = generate_race()
        vviq_responses = generate_vviq_responses()
        ideal_participation = generate_ideal_participation()
        attention_check_task = generate_attention_check_task()

        # Define the column names
        columns = ['EmailAddress', 'FutureContactConsent', 'Age', 'Sex', 'Ethnicity', 'Race'] + \
                  [f'VVIQ_Q{i+1}' for i in range(16)] + ['IdealParticipation', 'AttentionCheckTask']

        # Define the row data
        row = [email, consent, age, sex, ethnicity, race] + vviq_responses + [ideal_participation, attention_check_task]

        # Create a DataFrame
        df = pd.DataFrame([row], columns=columns)

        # Write to Parquet file
        df.to_parquet(f'./data/{filename}.parquet', index=False)

# %%
# Generate Parquet files
generate_parquet_files(200)

# %%
import boto3

# Create S3 client
s3 = boto3.client('s3', region_name='us-east-1')

# Define bucket name
bucket_name = 'exp-data-parquet'

# Create the S3 bucket
try:
    s3.create_bucket(Bucket=bucket_name)
    print(f'Bucket {bucket_name} created successfully.')
except s3.exceptions.BucketAlreadyOwnedByYou:
    print(f'Bucket {bucket_name} already exists and is owned by you.')
except Exception as e:
    print(f'Error creating bucket: {e}')
# Out:
# Bucket exp-data-parquet created successfully.

# %%
import os
import subprocess

# Function to upload a file to S3 using AWS CLI
def upload_file_to_s3_cli(file_name, bucket):
    command = f"aws s3 cp {file_name} s3://{bucket}/"
    try:
        result = subprocess.run(command, shell=True, check=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE)
        print(result.stdout.decode('utf-8'))
        return True
    except subprocess.CalledProcessError as e:
        print(f"Error uploading {file_name}: {e.stderr.decode('utf-8')}")
        return False

# Directory containing Parquet files
directory = './data/'

# S3 bucket name
bucket_name = 'exp-data-parquet'

# Upload all Parquet files in the directory to the S3 bucket
for filename in os.listdir(directory):
    if filename.endswith(".parquet"):
        file_path = os.path.join(directory, filename)
        success = upload_file_to_s3_cli(file_path, bucket_name)
        if success:
            print(f"Successfully uploaded {filename} to {bucket_name}")
        else:
            print(f"Failed to upload {filename}")
# Out:
# upload: data/in0ygjwyzi.parquet to s3://exp-data-parquet/in0ygjwyzi.parquet
#
# Successfully uploaded in0ygjwyzi.parquet to exp-data-parquet
# upload: data/70z5w73hrx.parquet to s3://exp-data-parquet/70z5w73hrx.parquet
#
# Successfully uploaded 70z5w73hrx.parquet to exp-data-parquet
# upload: data/gu4zap65kq.parquet to s3://exp-data-parquet/gu4zap65kq.parquet
#
# Successfully uploaded gu4zap65kq.parquet to exp-data-parquet
# upload: data/0yofabs7se.parquet to s3://exp-data-parquet/0yofabs7se.parquet
#
# Successfully uploaded 0yofabs7se.parquet to exp-data-parquet
# upload: data/48mq5t4v6e.parquet to s3://exp-data-parquet/48mq5t4v6e.parquet
#
# Successfully uploaded 48mq5t4v6e.parquet to exp-data-parquet
# upload: data/sbu3uy8wre.parquet to s3://exp-data-parquet/sbu3uy8wre.parquet
#
# Successfully uploaded sbu3uy8wre.parquet to exp-data-parquet
# upload: data/zixlh6hbh5.parquet to s3://exp-data-parquet/zixlh6hbh5.parquet
#
# Successfully uploaded zixlh6hbh5.parquet to exp-data-parquet
# upload: data/2tmd1xetkv.parquet to s3://exp-data-parquet/2tmd1xetkv.parquet
#
# Successfully uploaded 2tmd1xetkv.parquet to exp-data-parquet
# upload: data/pxguox9yzy.parquet to s3://exp-data-parquet/pxguox9yzy.parquet
#
# Successfully uploaded pxguox9yzy.parquet to exp-data-parquet
# upload: data/v9kgvi16a3.parquet to s3://exp-data-parquet/v9kgvi16a3.parquet
#
# Successfully uploaded v9kgvi16a3.parquet to exp-data-parquet
# upload: data/7dvv3ss6ny.parquet to s3://exp-data-parquet/7dvv3ss6ny.parquet
#
# Successfully uploaded 7dvv3ss6ny.parquet to exp-data-parquet
# upload: data/etp2y35mu2.parquet to s3://exp-data-parquet/etp2y35mu2.parquet
#
# Successfully uploaded etp2y35mu2.parquet to exp-data-parquet
# upload: data/fezqwgrthi.parquet to s3://exp-data-parquet/fezqwgrthi.parquet
#
# Successfully uploaded fezqwgrthi.parquet to exp-data-parquet
# upload: data/sz5vgarrvj.parquet to s3://exp-data-parquet/sz5vgarrvj.parquet
#
# Successfully uploaded sz5vgarrvj.parquet to exp-data-parquet
# upload: data/396vvsn8hn.parquet to s3://exp-data-parquet/396vvsn8hn.parquet
#
# Successfully uploaded 396vvsn8hn.parquet to exp-data-parquet
# upload: data/phge8enp71.parquet to s3://exp-data-parquet/phge8enp71.parquet
#
# Successfully uploaded phge8enp71.parquet to exp-data-parquet
# upload: data/95e24ic0qc.parquet to s3://exp-data-parquet/95e24ic0qc.parquet
#
# Successfully uploaded 95e24ic0qc.parquet to exp-data-parquet
# upload: data/dw0hrzr11b.parquet to s3://exp-data-parquet/dw0hrzr11b.parquet
#
# Successfully uploaded dw0hrzr11b.parquet to exp-data-parquet
# upload: data/fuqip725e4.parquet to s3://exp-data-parquet/fuqip725e4.parquet
#
# Successfully uploaded fuqip725e4.parquet to exp-data-parquet
# upload: data/es6f4x2jxi.parquet to s3://exp-data-parquet/es6f4x2jxi.parquet
#
# Successfully uploaded es6f4x2jxi.parquet to exp-data-parquet
# upload: data/6i01pra377.parquet to s3://exp-data-parquet/6i01pra377.parquet
#
# Successfully uploaded 6i01pra377.parquet to exp-data-parquet
# upload: data/p2vtsbn0ms.parquet to s3://exp-data-parquet/p2vtsbn0ms.parquet
#
# Successfully uploaded p2vtsbn0ms.parquet to exp-data-parquet
# upload: data/8zzuwobjlr.parquet to s3://exp-data-parquet/8zzuwobjlr.parquet
#
# Successfully uploaded 8zzuwobjlr.parquet to exp-data-parquet
# upload: data/ygechsi2jr.parquet to s3://exp-data-parquet/ygechsi2jr.parquet
#
# Successfully uploaded ygechsi2jr.parquet to exp-data-parquet
# upload: data/dwlgyfg2jl.parquet to s3://exp-data-parquet/dwlgyfg2jl.parquet
#
# Successfully uploaded dwlgyfg2jl.parquet to exp-data-parquet
# upload: data/v3qjitfvni.parquet to s3://exp-data-parquet/v3qjitfvni.parquet
#
# Successfully uploaded v3qjitfvni.parquet to exp-data-parquet
# upload: data/1i4dgd97m3.parquet to s3://exp-data-parquet/1i4dgd97m3.parquet
#
# Successfully uploaded 1i4dgd97m3.parquet to exp-data-parquet
# upload: data/vcixp5fz70.parquet to s3://exp-data-parquet/vcixp5fz70.parquet
#
# Successfully uploaded vcixp5fz70.parquet to exp-data-parquet
# upload: data/xhctf6010h.parquet to s3://exp-data-parquet/xhctf6010h.parquet
#
# Successfully uploaded xhctf6010h.parquet to exp-data-parquet
# upload: data/lg1b3ebgy4.parquet to s3://exp-data-parquet/lg1b3ebgy4.parquet
#
# Successfully uploaded lg1b3ebgy4.parquet to exp-data-parquet
# upload: data/uykgbkdshi.parquet to s3://exp-data-parquet/uykgbkdshi.parquet
#
# Successfully uploaded uykgbkdshi.parquet to exp-data-parquet
# upload: data/jqe440xbl7.parquet to s3://exp-data-parquet/jqe440xbl7.parquet
#
# Successfully uploaded jqe440xbl7.parquet to exp-data-parquet
# upload: data/wtr4rp8j5p.parquet to s3://exp-data-parquet/wtr4rp8j5p.parquet
#
# Successfully uploaded wtr4rp8j5p.parquet to exp-data-parquet
# upload: data/gl58dodp72.parquet to s3://exp-data-parquet/gl58dodp72.parquet
#
# Successfully uploaded gl58dodp72.parquet to exp-data-parquet
# upload: data/x9e2syyeri.parquet to s3://exp-data-parquet/x9e2syyeri.parquet
#
# Successfully uploaded x9e2syyeri.parquet to exp-data-parquet
# upload: data/dz8zw51fup.parquet to s3://exp-data-parquet/dz8zw51fup.parquet
#
# Successfully uploaded dz8zw51fup.parquet to exp-data-parquet
# upload: data/ypyzigczm6.parquet to s3://exp-data-parquet/ypyzigczm6.parquet
#
# Successfully uploaded ypyzigczm6.parquet to exp-data-parquet
# upload: data/rj2mjtih4z.parquet to s3://exp-data-parquet/rj2mjtih4z.parquet
#
# Successfully uploaded rj2mjtih4z.parquet to exp-data-parquet
# upload: data/lbxo0hq58d.parquet to s3://exp-data-parquet/lbxo0hq58d.parquet
#
# Successfully uploaded lbxo0hq58d.parquet to exp-data-parquet
# upload: data/lo56n48t4q.parquet to s3://exp-data-parquet/lo56n48t4q.parquet
#
# Successfully uploaded lo56n48t4q.parquet to exp-data-parquet
# upload: data/0qa175qzmn.parquet to s3://exp-data-parquet/0qa175qzmn.parquet
#
# Successfully uploaded 0qa175qzmn.parquet to exp-data-parquet
# upload: data/yi6684t409.parquet to s3://exp-data-parquet/yi6684t409.parquet
#
# Successfully uploaded yi6684t409.parquet to exp-data-parquet
# upload: data/726tb97mzg.parquet to s3://exp-data-parquet/726tb97mzg.parquet
#
# Successfully uploaded 726tb97mzg.parquet to exp-data-parquet
# upload: data/hr14bux9rs.parquet to s3://exp-data-parquet/hr14bux9rs.parquet
#
# Successfully uploaded hr14bux9rs.parquet to exp-data-parquet
# upload: data/z7eef6qj8u.parquet to s3://exp-data-parquet/z7eef6qj8u.parquet
#
# Successfully uploaded z7eef6qj8u.parquet to exp-data-parquet
# upload: data/ul1ixkkn2i.parquet to s3://exp-data-parquet/ul1ixkkn2i.parquet
#
# Successfully uploaded ul1ixkkn2i.parquet to exp-data-parquet
# upload: data/7tx613qz6g.parquet to s3://exp-data-parquet/7tx613qz6g.parquet
#
# Successfully uploaded 7tx613qz6g.parquet to exp-data-parquet
# upload: data/pog8go5lp7.parquet to s3://exp-data-parquet/pog8go5lp7.parquet
#
# Successfully uploaded pog8go5lp7.parquet to exp-data-parquet
# upload: data/4l8eow9pc5.parquet to s3://exp-data-parquet/4l8eow9pc5.parquet
#
# Successfully uploaded 4l8eow9pc5.parquet to exp-data-parquet
# upload: data/nx6of9jlrq.parquet to s3://exp-data-parquet/nx6of9jlrq.parquet
#
# Successfully uploaded nx6of9jlrq.parquet to exp-data-parquet
# upload: data/jkvyvd4lj2.parquet to s3://exp-data-parquet/jkvyvd4lj2.parquet
#
# Successfully uploaded jkvyvd4lj2.parquet to exp-data-parquet
# upload: data/7yd3rs0y65.parquet to s3://exp-data-parquet/7yd3rs0y65.parquet
#
# Successfully uploaded 7yd3rs0y65.parquet to exp-data-parquet
# upload: data/v11jssqgrj.parquet to s3://exp-data-parquet/v11jssqgrj.parquet
#
# Successfully uploaded v11jssqgrj.parquet to exp-data-parquet
# upload: data/climvbet61.parquet to s3://exp-data-parquet/climvbet61.parquet
#
# Successfully uploaded climvbet61.parquet to exp-data-parquet
# upload: data/trfjn5qisb.parquet to s3://exp-data-parquet/trfjn5qisb.parquet
#
# Successfully uploaded trfjn5qisb.parquet to exp-data-parquet
# upload: data/3y8d6aejaj.parquet to s3://exp-data-parquet/3y8d6aejaj.parquet
#
# Successfully uploaded 3y8d6aejaj.parquet to exp-data-parquet
# upload: data/4enptdoyoa.parquet to s3://exp-data-parquet/4enptdoyoa.parquet
#
# Successfully uploaded 4enptdoyoa.parquet to exp-data-parquet
# upload: data/2gcy5cm42i.parquet to s3://exp-data-parquet/2gcy5cm42i.parquet
#
# Successfully uploaded 2gcy5cm42i.parquet to exp-data-parquet
# upload: data/rfthh6njkx.parquet to s3://exp-data-parquet/rfthh6njkx.parquet
#
# Successfully uploaded rfthh6njkx.parquet to exp-data-parquet
# upload: data/jp3vh0t1cu.parquet to s3://exp-data-parquet/jp3vh0t1cu.parquet
#
# Successfully uploaded jp3vh0t1cu.parquet to exp-data-parquet
# upload: data/m998ytl1uj.parquet to s3://exp-data-parquet/m998ytl1uj.parquet
#
# Successfully uploaded m998ytl1uj.parquet to exp-data-parquet
# upload: data/k8fgjcvusi.parquet to s3://exp-data-parquet/k8fgjcvusi.parquet
#
# Successfully uploaded k8fgjcvusi.parquet to exp-data-parquet
# upload: data/6o8t8q4b9j.parquet to s3://exp-data-parquet/6o8t8q4b9j.parquet
#
# Successfully uploaded 6o8t8q4b9j.parquet to exp-data-parquet
# upload: data/pzqqmhddkd.parquet to s3://exp-data-parquet/pzqqmhddkd.parquet
#
# Successfully uploaded pzqqmhddkd.parquet to exp-data-parquet
# upload: data/fdzgdgbx1e.parquet to s3://exp-data-parquet/fdzgdgbx1e.parquet
#
# Successfully uploaded fdzgdgbx1e.parquet to exp-data-parquet
# upload: data/d8bhwk90je.parquet to s3://exp-data-parquet/d8bhwk90je.parquet
#
# Successfully uploaded d8bhwk90je.parquet to exp-data-parquet
# upload: data/3smyws11s4.parquet to s3://exp-data-parquet/3smyws11s4.parquet
#
# Successfully uploaded 3smyws11s4.parquet to exp-data-parquet
# upload: data/lsmca2pd74.parquet to s3://exp-data-parquet/lsmca2pd74.parquet
#
# Successfully uploaded lsmca2pd74.parquet to exp-data-parquet
# upload: data/3mvrbcwto0.parquet to s3://exp-data-parquet/3mvrbcwto0.parquet
#
# Successfully uploaded 3mvrbcwto0.parquet to exp-data-parquet
# upload: data/r7m67f8t6x.parquet to s3://exp-data-parquet/r7m67f8t6x.parquet
#
# Successfully uploaded r7m67f8t6x.parquet to exp-data-parquet
# upload: data/uxa80d98x3.parquet to s3://exp-data-parquet/uxa80d98x3.parquet
#
# Successfully uploaded uxa80d98x3.parquet to exp-data-parquet
# upload: data/3wx2etrpt6.parquet to s3://exp-data-parquet/3wx2etrpt6.parquet
#
# Successfully uploaded 3wx2etrpt6.parquet to exp-data-parquet
# upload: data/cr3tl5f9tz.parquet to s3://exp-data-parquet/cr3tl5f9tz.parquet
#
# Successfully uploaded cr3tl5f9tz.parquet to exp-data-parquet
# upload: data/opgab563e6.parquet to s3://exp-data-parquet/opgab563e6.parquet
#
# Successfully uploaded opgab563e6.parquet to exp-data-parquet
# upload: data/y7uxaxmbgb.parquet to s3://exp-data-parquet/y7uxaxmbgb.parquet
#
# Successfully uploaded y7uxaxmbgb.parquet to exp-data-parquet
# upload: data/6acj8jzbwd.parquet to s3://exp-data-parquet/6acj8jzbwd.parquet
#
# Successfully uploaded 6acj8jzbwd.parquet to exp-data-parquet
# upload: data/hf3edxpl7h.parquet to s3://exp-data-parquet/hf3edxpl7h.parquet
#
# Successfully uploaded hf3edxpl7h.parquet to exp-data-parquet
# upload: data/sxrl60bne2.parquet to s3://exp-data-parquet/sxrl60bne2.parquet
#
# Successfully uploaded sxrl60bne2.parquet to exp-data-parquet
# upload: data/pg6u203631.parquet to s3://exp-data-parquet/pg6u203631.parquet
#
# Successfully uploaded pg6u203631.parquet to exp-data-parquet
# upload: data/3e32vhjzy1.parquet to s3://exp-data-parquet/3e32vhjzy1.parquet
#
# Successfully uploaded 3e32vhjzy1.parquet to exp-data-parquet
# upload: data/hhxi4jxok2.parquet to s3://exp-data-parquet/hhxi4jxok2.parquet
#
# Successfully uploaded hhxi4jxok2.parquet to exp-data-parquet
# upload: data/j4s1u9uruu.parquet to s3://exp-data-parquet/j4s1u9uruu.parquet
#
# Successfully uploaded j4s1u9uruu.parquet to exp-data-parquet
# upload: data/qdfqmdmww4.parquet to s3://exp-data-parquet/qdfqmdmww4.parquet
#
# Successfully uploaded qdfqmdmww4.parquet to exp-data-parquet
# upload: data/38ml5hf0dx.parquet to s3://exp-data-parquet/38ml5hf0dx.parquet
#
# Successfully uploaded 38ml5hf0dx.parquet to exp-data-parquet
# upload: data/3x1ri3r8kg.parquet to s3://exp-data-parquet/3x1ri3r8kg.parquet
#
# Successfully uploaded 3x1ri3r8kg.parquet to exp-data-parquet
# upload: data/h9e681stj9.parquet to s3://exp-data-parquet/h9e681stj9.parquet
#
# Successfully uploaded h9e681stj9.parquet to exp-data-parquet
# upload: data/in2b8bz2vl.parquet to s3://exp-data-parquet/in2b8bz2vl.parquet
#
# Successfully uploaded in2b8bz2vl.parquet to exp-data-parquet
# upload: data/2z8cq3s5rd.parquet to s3://exp-data-parquet/2z8cq3s5rd.parquet
#
# Successfully uploaded 2z8cq3s5rd.parquet to exp-data-parquet
# upload: data/19wspycaqb.parquet to s3://exp-data-parquet/19wspycaqb.parquet
#
# Successfully uploaded 19wspycaqb.parquet to exp-data-parquet
# upload: data/lzo16sfwcx.parquet to s3://exp-data-parquet/lzo16sfwcx.parquet
#
# Successfully uploaded lzo16sfwcx.parquet to exp-data-parquet
# upload: data/sqjex4h3lp.parquet to s3://exp-data-parquet/sqjex4h3lp.parquet
#
# Successfully uploaded sqjex4h3lp.parquet to exp-data-parquet
# upload: data/3xonogz2k9.parquet to s3://exp-data-parquet/3xonogz2k9.parquet
#
# Successfully uploaded 3xonogz2k9.parquet to exp-data-parquet
# upload: data/8l78evaync.parquet to s3://exp-data-parquet/8l78evaync.parquet
#
# Successfully uploaded 8l78evaync.parquet to exp-data-parquet
# upload: data/z0z4o8x2sp.parquet to s3://exp-data-parquet/z0z4o8x2sp.parquet
#
# Successfully uploaded z0z4o8x2sp.parquet to exp-data-parquet
# upload: data/7p5niy1gtu.parquet to s3://exp-data-parquet/7p5niy1gtu.parquet
#
# Successfully uploaded 7p5niy1gtu.parquet to exp-data-parquet
# upload: data/6j7tb8t04r.parquet to s3://exp-data-parquet/6j7tb8t04r.parquet
#
# Successfully uploaded 6j7tb8t04r.parquet to exp-data-parquet
# upload: data/x3fmbwhqm6.parquet to s3://exp-data-parquet/x3fmbwhqm6.parquet
#
# Successfully uploaded x3fmbwhqm6.parquet to exp-data-parquet
# upload: data/7eylttq5nq.parquet to s3://exp-data-parquet/7eylttq5nq.parquet
#
# Successfully uploaded 7eylttq5nq.parquet to exp-data-parquet
# upload: data/partt95v64.parquet to s3://exp-data-parquet/partt95v64.parquet
#
# Successfully uploaded partt95v64.parquet to exp-data-parquet
# upload: data/y4yde5w2nw.parquet to s3://exp-data-parquet/y4yde5w2nw.parquet
#
# Successfully uploaded y4yde5w2nw.parquet to exp-data-parquet
# upload: data/5qnht75xjy.parquet to s3://exp-data-parquet/5qnht75xjy.parquet
#
# Successfully uploaded 5qnht75xjy.parquet to exp-data-parquet
# upload: data/rlanxfd9h8.parquet to s3://exp-data-parquet/rlanxfd9h8.parquet
#
# Successfully uploaded rlanxfd9h8.parquet to exp-data-parquet
# upload: data/hz3m1e0tac.parquet to s3://exp-data-parquet/hz3m1e0tac.parquet
#
# Successfully uploaded hz3m1e0tac.parquet to exp-data-parquet
# upload: data/m6yc6ebvi1.parquet to s3://exp-data-parquet/m6yc6ebvi1.parquet
#
# Successfully uploaded m6yc6ebvi1.parquet to exp-data-parquet
# upload: data/ikhs8jmee7.parquet to s3://exp-data-parquet/ikhs8jmee7.parquet
#
# Successfully uploaded ikhs8jmee7.parquet to exp-data-parquet
# upload: data/7xyd3qe8a1.parquet to s3://exp-data-parquet/7xyd3qe8a1.parquet
#
# Successfully uploaded 7xyd3qe8a1.parquet to exp-data-parquet
# upload: data/z5s0rjsm4p.parquet to s3://exp-data-parquet/z5s0rjsm4p.parquet
#
# Successfully uploaded z5s0rjsm4p.parquet to exp-data-parquet
# upload: data/bqmqo2d5ps.parquet to s3://exp-data-parquet/bqmqo2d5ps.parquet
#
# Successfully uploaded bqmqo2d5ps.parquet to exp-data-parquet
# upload: data/qril0pv7t1.parquet to s3://exp-data-parquet/qril0pv7t1.parquet
#
# Successfully uploaded qril0pv7t1.parquet to exp-data-parquet
# upload: data/v3ktzqofo9.parquet to s3://exp-data-parquet/v3ktzqofo9.parquet
#
# Successfully uploaded v3ktzqofo9.parquet to exp-data-parquet
# upload: data/53yt5qrkcw.parquet to s3://exp-data-parquet/53yt5qrkcw.parquet
#
# Successfully uploaded 53yt5qrkcw.parquet to exp-data-parquet
# upload: data/eo0z8ykzdg.parquet to s3://exp-data-parquet/eo0z8ykzdg.parquet
#
# Successfully uploaded eo0z8ykzdg.parquet to exp-data-parquet
# upload: data/4q052hx31s.parquet to s3://exp-data-parquet/4q052hx31s.parquet
#
# Successfully uploaded 4q052hx31s.parquet to exp-data-parquet
# upload: data/hekvj9y8yl.parquet to s3://exp-data-parquet/hekvj9y8yl.parquet
#
# Successfully uploaded hekvj9y8yl.parquet to exp-data-parquet
# upload: data/ov2dk70va7.parquet to s3://exp-data-parquet/ov2dk70va7.parquet
#
# Successfully uploaded ov2dk70va7.parquet to exp-data-parquet
# upload: data/vb724j1hkh.parquet to s3://exp-data-parquet/vb724j1hkh.parquet
#
# Successfully uploaded vb724j1hkh.parquet to exp-data-parquet
# upload: data/vq9o7uj8ju.parquet to s3://exp-data-parquet/vq9o7uj8ju.parquet
#
# Successfully uploaded vq9o7uj8ju.parquet to exp-data-parquet
# upload: data/xbnxqe5pne.parquet to s3://exp-data-parquet/xbnxqe5pne.parquet
#
# Successfully uploaded xbnxqe5pne.parquet to exp-data-parquet
# upload: data/ik87zz580g.parquet to s3://exp-data-parquet/ik87zz580g.parquet
#
# Successfully uploaded ik87zz580g.parquet to exp-data-parquet
# upload: data/crgj29qjtb.parquet to s3://exp-data-parquet/crgj29qjtb.parquet
#
# Successfully uploaded crgj29qjtb.parquet to exp-data-parquet
# upload: data/2syoniq5tq.parquet to s3://exp-data-parquet/2syoniq5tq.parquet
#
# Successfully uploaded 2syoniq5tq.parquet to exp-data-parquet
# upload: data/d0j667ohs4.parquet to s3://exp-data-parquet/d0j667ohs4.parquet
#
# Successfully uploaded d0j667ohs4.parquet to exp-data-parquet
# upload: data/afdd56ach1.parquet to s3://exp-data-parquet/afdd56ach1.parquet
#
# Successfully uploaded afdd56ach1.parquet to exp-data-parquet
# upload: data/qtb50sbqwx.parquet to s3://exp-data-parquet/qtb50sbqwx.parquet
#
# Successfully uploaded qtb50sbqwx.parquet to exp-data-parquet
# upload: data/fskwwjke39.parquet to s3://exp-data-parquet/fskwwjke39.parquet
#
# Successfully uploaded fskwwjke39.parquet to exp-data-parquet
# upload: data/zo3ir981th.parquet to s3://exp-data-parquet/zo3ir981th.parquet
#
# Successfully uploaded zo3ir981th.parquet to exp-data-parquet
# upload: data/j815jyvnd6.parquet to s3://exp-data-parquet/j815jyvnd6.parquet
#
# Successfully uploaded j815jyvnd6.parquet to exp-data-parquet
# upload: data/s0thu77s6g.parquet to s3://exp-data-parquet/s0thu77s6g.parquet
#
# Successfully uploaded s0thu77s6g.parquet to exp-data-parquet
# upload: data/eecxg1q25q.parquet to s3://exp-data-parquet/eecxg1q25q.parquet
#
# Successfully uploaded eecxg1q25q.parquet to exp-data-parquet
# upload: data/4o5opcpx2b.parquet to s3://exp-data-parquet/4o5opcpx2b.parquet
#
# Successfully uploaded 4o5opcpx2b.parquet to exp-data-parquet
# upload: data/lno53dakx5.parquet to s3://exp-data-parquet/lno53dakx5.parquet
#
# Successfully uploaded lno53dakx5.parquet to exp-data-parquet
# upload: data/eks788d6fh.parquet to s3://exp-data-parquet/eks788d6fh.parquet
#
# Successfully uploaded eks788d6fh.parquet to exp-data-parquet
# upload: data/erwvftxrc5.parquet to s3://exp-data-parquet/erwvftxrc5.parquet
#
# Successfully uploaded erwvftxrc5.parquet to exp-data-parquet
# upload: data/g4tlunly5c.parquet to s3://exp-data-parquet/g4tlunly5c.parquet
#
# Successfully uploaded g4tlunly5c.parquet to exp-data-parquet
# upload: data/hifdltf66y.parquet to s3://exp-data-parquet/hifdltf66y.parquet
#
# Successfully uploaded hifdltf66y.parquet to exp-data-parquet
# upload: data/a9buszoz26.parquet to s3://exp-data-parquet/a9buszoz26.parquet
#
# Successfully uploaded a9buszoz26.parquet to exp-data-parquet
# upload: data/lb9wq6jv53.parquet to s3://exp-data-parquet/lb9wq6jv53.parquet
#
# Successfully uploaded lb9wq6jv53.parquet to exp-data-parquet
# upload: data/3r2l39udlp.parquet to s3://exp-data-parquet/3r2l39udlp.parquet
#
# Successfully uploaded 3r2l39udlp.parquet to exp-data-parquet
# upload: data/0ew2g7jfla.parquet to s3://exp-data-parquet/0ew2g7jfla.parquet
#
# Successfully uploaded 0ew2g7jfla.parquet to exp-data-parquet
# upload: data/t5o9igg105.parquet to s3://exp-data-parquet/t5o9igg105.parquet
#
# Successfully uploaded t5o9igg105.parquet to exp-data-parquet
# upload: data/qmbqtfzftn.parquet to s3://exp-data-parquet/qmbqtfzftn.parquet
#
# Successfully uploaded qmbqtfzftn.parquet to exp-data-parquet
# upload: data/qbvnv9jzoo.parquet to s3://exp-data-parquet/qbvnv9jzoo.parquet
#
# Successfully uploaded qbvnv9jzoo.parquet to exp-data-parquet
# upload: data/7rd31d5vci.parquet to s3://exp-data-parquet/7rd31d5vci.parquet
#
# Successfully uploaded 7rd31d5vci.parquet to exp-data-parquet
# upload: data/aqj21awgbf.parquet to s3://exp-data-parquet/aqj21awgbf.parquet
#
# Successfully uploaded aqj21awgbf.parquet to exp-data-parquet
# upload: data/xdq687wdte.parquet to s3://exp-data-parquet/xdq687wdte.parquet
#
# Successfully uploaded xdq687wdte.parquet to exp-data-parquet
# upload: data/gorq7e4j0w.parquet to s3://exp-data-parquet/gorq7e4j0w.parquet
#
# Successfully uploaded gorq7e4j0w.parquet to exp-data-parquet
# upload: data/poqnjid6ch.parquet to s3://exp-data-parquet/poqnjid6ch.parquet
#
# Successfully uploaded poqnjid6ch.parquet to exp-data-parquet
# upload: data/yrrdo2idps.parquet to s3://exp-data-parquet/yrrdo2idps.parquet
#
# Successfully uploaded yrrdo2idps.parquet to exp-data-parquet
# upload: data/8mh4ao4thm.parquet to s3://exp-data-parquet/8mh4ao4thm.parquet
#
# Successfully uploaded 8mh4ao4thm.parquet to exp-data-parquet
# upload: data/wbmvr4ccm2.parquet to s3://exp-data-parquet/wbmvr4ccm2.parquet
#
# Successfully uploaded wbmvr4ccm2.parquet to exp-data-parquet
# upload: data/i29ui2ssd9.parquet to s3://exp-data-parquet/i29ui2ssd9.parquet
#
# Successfully uploaded i29ui2ssd9.parquet to exp-data-parquet
# upload: data/r0v6p2gfz5.parquet to s3://exp-data-parquet/r0v6p2gfz5.parquet
#
# Successfully uploaded r0v6p2gfz5.parquet to exp-data-parquet
# upload: data/8ogk04msmd.parquet to s3://exp-data-parquet/8ogk04msmd.parquet
#
# Successfully uploaded 8ogk04msmd.parquet to exp-data-parquet
# upload: data/t51zn0n1na.parquet to s3://exp-data-parquet/t51zn0n1na.parquet
#
# Successfully uploaded t51zn0n1na.parquet to exp-data-parquet
# upload: data/oyreas5tv7.parquet to s3://exp-data-parquet/oyreas5tv7.parquet
#
# Successfully uploaded oyreas5tv7.parquet to exp-data-parquet
# upload: data/h3pusayhz6.parquet to s3://exp-data-parquet/h3pusayhz6.parquet
#
# Successfully uploaded h3pusayhz6.parquet to exp-data-parquet
# upload: data/xntinjn90u.parquet to s3://exp-data-parquet/xntinjn90u.parquet
#
# Successfully uploaded xntinjn90u.parquet to exp-data-parquet
# upload: data/hate3kpzc8.parquet to s3://exp-data-parquet/hate3kpzc8.parquet
#
# Successfully uploaded hate3kpzc8.parquet to exp-data-parquet
# upload: data/ryjoedcwup.parquet to s3://exp-data-parquet/ryjoedcwup.parquet
#
# Successfully uploaded ryjoedcwup.parquet to exp-data-parquet
# upload: data/k15thshzyp.parquet to s3://exp-data-parquet/k15thshzyp.parquet
#
# Successfully uploaded k15thshzyp.parquet to exp-data-parquet
# upload: data/sq5n5jbqjl.parquet to s3://exp-data-parquet/sq5n5jbqjl.parquet
#
# Successfully uploaded sq5n5jbqjl.parquet to exp-data-parquet
# upload: data/htrv2g932g.parquet to s3://exp-data-parquet/htrv2g932g.parquet
#
# Successfully uploaded htrv2g932g.parquet to exp-data-parquet
# upload: data/wi1pqcssne.parquet to s3://exp-data-parquet/wi1pqcssne.parquet
#
# Successfully uploaded wi1pqcssne.parquet to exp-data-parquet
# upload: data/vmid6f45oc.parquet to s3://exp-data-parquet/vmid6f45oc.parquet
#
# Successfully uploaded vmid6f45oc.parquet to exp-data-parquet
# upload: data/n7vgh3fbpy.parquet to s3://exp-data-parquet/n7vgh3fbpy.parquet
#
# Successfully uploaded n7vgh3fbpy.parquet to exp-data-parquet
# upload: data/9ktaiva0di.parquet to s3://exp-data-parquet/9ktaiva0di.parquet
#
# Successfully uploaded 9ktaiva0di.parquet to exp-data-parquet
# upload: data/4nar8btra5.parquet to s3://exp-data-parquet/4nar8btra5.parquet
#
# Successfully uploaded 4nar8btra5.parquet to exp-data-parquet
# upload: data/2amk5u3cgd.parquet to s3://exp-data-parquet/2amk5u3cgd.parquet
#
# Successfully uploaded 2amk5u3cgd.parquet to exp-data-parquet
# upload: data/9pav9eseke.parquet to s3://exp-data-parquet/9pav9eseke.parquet
#
# Successfully uploaded 9pav9eseke.parquet to exp-data-parquet
# upload: data/ay3j8it15q.parquet to s3://exp-data-parquet/ay3j8it15q.parquet
#
# Successfully uploaded ay3j8it15q.parquet to exp-data-parquet
# upload: data/wpd6opaa1m.parquet to s3://exp-data-parquet/wpd6opaa1m.parquet
#
# Successfully uploaded wpd6opaa1m.parquet to exp-data-parquet
# upload: data/p7nfmpq0a8.parquet to s3://exp-data-parquet/p7nfmpq0a8.parquet
#
# Successfully uploaded p7nfmpq0a8.parquet to exp-data-parquet
# upload: data/tv7kpw8o7w.parquet to s3://exp-data-parquet/tv7kpw8o7w.parquet
#
# Successfully uploaded tv7kpw8o7w.parquet to exp-data-parquet
# upload: data/b55hj2z1hq.parquet to s3://exp-data-parquet/b55hj2z1hq.parquet
#
# Successfully uploaded b55hj2z1hq.parquet to exp-data-parquet
# upload: data/j9vb4bqakq.parquet to s3://exp-data-parquet/j9vb4bqakq.parquet
#
# Successfully uploaded j9vb4bqakq.parquet to exp-data-parquet
# upload: data/v6ozawvmc6.parquet to s3://exp-data-parquet/v6ozawvmc6.parquet
#
# Successfully uploaded v6ozawvmc6.parquet to exp-data-parquet
# upload: data/c4xjudnq2z.parquet to s3://exp-data-parquet/c4xjudnq2z.parquet
#
# Successfully uploaded c4xjudnq2z.parquet to exp-data-parquet
# upload: data/xrvunj7ivi.parquet to s3://exp-data-parquet/xrvunj7ivi.parquet
#
# Successfully uploaded xrvunj7ivi.parquet to exp-data-parquet
# upload: data/muzom0tm6x.parquet to s3://exp-data-parquet/muzom0tm6x.parquet
#
# Successfully uploaded muzom0tm6x.parquet to exp-data-parquet
# upload: data/jfied1il87.parquet to s3://exp-data-parquet/jfied1il87.parquet
#
# Successfully uploaded jfied1il87.parquet to exp-data-parquet
# upload: data/4auxgl5oja.parquet to s3://exp-data-parquet/4auxgl5oja.parquet
#
# Successfully uploaded 4auxgl5oja.parquet to exp-data-parquet
# upload: data/d2vlphhmey.parquet to s3://exp-data-parquet/d2vlphhmey.parquet
#
# Successfully uploaded d2vlphhmey.parquet to exp-data-parquet
# upload: data/7vum8xytf9.parquet to s3://exp-data-parquet/7vum8xytf9.parquet
#
# Successfully uploaded 7vum8xytf9.parquet to exp-data-parquet
# upload: data/1czlbmtpxs.parquet to s3://exp-data-parquet/1czlbmtpxs.parquet
#
# Successfully uploaded 1czlbmtpxs.parquet to exp-data-parquet
# upload: data/rdw4whjl2k.parquet to s3://exp-data-parquet/rdw4whjl2k.parquet
#
# Successfully uploaded rdw4whjl2k.parquet to exp-data-parquet
# upload: data/gqy3mtffco.parquet to s3://exp-data-parquet/gqy3mtffco.parquet
#
# Successfully uploaded gqy3mtffco.parquet to exp-data-parquet
# upload: data/i6zk0q6jaf.parquet to s3://exp-data-parquet/i6zk0q6jaf.parquet
#
# Successfully uploaded i6zk0q6jaf.parquet to exp-data-parquet
# upload: data/szi4hn9mav.parquet to s3://exp-data-parquet/szi4hn9mav.parquet
#
# Successfully uploaded szi4hn9mav.parquet to exp-data-parquet
# upload: data/insasj8at3.parquet to s3://exp-data-parquet/insasj8at3.parquet
#
# Successfully uploaded insasj8at3.parquet to exp-data-parquet
# upload: data/la2jrbcf0o.parquet to s3://exp-data-parquet/la2jrbcf0o.parquet
#
# Successfully uploaded la2jrbcf0o.parquet to exp-data-parquet
# upload: data/r4jc84o0qz.parquet to s3://exp-data-parquet/r4jc84o0qz.parquet
#
# Successfully uploaded r4jc84o0qz.parquet to exp-data-parquet
# upload: data/bf1ca2yj92.parquet to s3://exp-data-parquet/bf1ca2yj92.parquet
#
# Successfully uploaded bf1ca2yj92.parquet to exp-data-parquet
# upload: data/f69i2ei450.parquet to s3://exp-data-parquet/f69i2ei450.parquet
#
# Successfully uploaded f69i2ei450.parquet to exp-data-parquet
# upload: data/2jth6vvh0d.parquet to s3://exp-data-parquet/2jth6vvh0d.parquet
#
# Successfully uploaded 2jth6vvh0d.parquet to exp-data-parquet
# upload: data/jwbrexteac.parquet to s3://exp-data-parquet/jwbrexteac.parquet
#
# Successfully uploaded jwbrexteac.parquet to exp-data-parquet
# upload: data/9tmhqldp29.parquet to s3://exp-data-parquet/9tmhqldp29.parquet
#
# Successfully uploaded 9tmhqldp29.parquet to exp-data-parquet
# upload: data/tsm2z2ncmn.parquet to s3://exp-data-parquet/tsm2z2ncmn.parquet
#
# Successfully uploaded tsm2z2ncmn.parquet to exp-data-parquet
# upload: data/stpgk0v04r.parquet to s3://exp-data-parquet/stpgk0v04r.parquet
#
# Successfully uploaded stpgk0v04r.parquet to exp-data-parquet
# upload: data/b0iokv2vul.parquet to s3://exp-data-parquet/b0iokv2vul.parquet
#
# Successfully uploaded b0iokv2vul.parquet to exp-data-parquet
# upload: data/9siqeq886g.parquet to s3://exp-data-parquet/9siqeq886g.parquet
#
# Successfully uploaded 9siqeq886g.parquet to exp-data-parquet
# upload: data/8bb32fwvkx.parquet to s3://exp-data-parquet/8bb32fwvkx.parquet
#
# Successfully uploaded 8bb32fwvkx.parquet to exp-data-parquet
# upload: data/yloq4axryl.parquet to s3://exp-data-parquet/yloq4axryl.parquet
#
# Successfully uploaded yloq4axryl.parquet to exp-data-parquet
# upload: data/n80t3vh4qv.parquet to s3://exp-data-parquet/n80t3vh4qv.parquet
#
# Successfully uploaded n80t3vh4qv.parquet to exp-data-parquet
# upload: data/dluorwikdk.parquet to s3://exp-data-parquet/dluorwikdk.parquet
#
# Successfully uploaded dluorwikdk.parquet to exp-data-parquet
# upload: data/wgk18ldtmr.parquet to s3://exp-data-parquet/wgk18ldtmr.parquet
#
# Successfully uploaded wgk18ldtmr.parquet to exp-data-parquet
# upload: data/xzbf0rpqv2.parquet to s3://exp-data-parquet/xzbf0rpqv2.parquet
#
# Successfully uploaded xzbf0rpqv2.parquet to exp-data-parquet
# upload: data/ssb27wwroc.parquet to s3://exp-data-parquet/ssb27wwroc.parquet
#
# Successfully uploaded ssb27wwroc.parquet to exp-data-parquet
# upload: data/lzo82q157d.parquet to s3://exp-data-parquet/lzo82q157d.parquet
#
# Successfully uploaded lzo82q157d.parquet to exp-data-parquet
# upload: data/y9esnlx5vp.parquet to s3://exp-data-parquet/y9esnlx5vp.parquet
#
# Successfully uploaded y9esnlx5vp.parquet to exp-data-parquet
# upload: data/dsan87l3jf.parquet to s3://exp-data-parquet/dsan87l3jf.parquet
#
# Successfully uploaded dsan87l3jf.parquet to exp-data-parquet
# upload: data/ilmelxb2gl.parquet to s3://exp-data-parquet/ilmelxb2gl.parquet
#
# Successfully uploaded ilmelxb2gl.parquet to exp-data-parquet
# upload: data/m19wi9bhda.parquet to s3://exp-data-parquet/m19wi9bhda.parquet
#
# Successfully uploaded m19wi9bhda.parquet to exp-data-parquet
# upload: data/amxepijc5p.parquet to s3://exp-data-parquet/amxepijc5p.parquet
#
# Successfully uploaded amxepijc5p.parquet to exp-data-parquet
# upload: data/9x8r3yxn9y.parquet to s3://exp-data-parquet/9x8r3yxn9y.parquet
#
# Successfully uploaded 9x8r3yxn9y.parquet to exp-data-parquet
# upload: data/gb1vz651g8.parquet to s3://exp-data-parquet/gb1vz651g8.parquet
#
# Successfully uploaded gb1vz651g8.parquet to exp-data-parquet
# upload: data/dgwn46ny48.parquet to s3://exp-data-parquet/dgwn46ny48.parquet
#
# Successfully uploaded dgwn46ny48.parquet to exp-data-parquet
# upload: data/u83cyyzh4k.parquet to s3://exp-data-parquet/u83cyyzh4k.parquet
#
# Successfully uploaded u83cyyzh4k.parquet to exp-data-parquet
# upload: data/y4655zphpk.parquet to s3://exp-data-parquet/y4655zphpk.parquet
#
# Successfully uploaded y4655zphpk.parquet to exp-data-parquet
# upload: data/9zktphvymz.parquet to s3://exp-data-parquet/9zktphvymz.parquet
#
# Successfully uploaded 9zktphvymz.parquet to exp-data-parquet
# upload: data/tsqfvmlo59.parquet to s3://exp-data-parquet/tsqfvmlo59.parquet
#
# Successfully uploaded tsqfvmlo59.parquet to exp-data-parquet
# upload: data/2c1z3zfvrj.parquet to s3://exp-data-parquet/2c1z3zfvrj.parquet
#
# Successfully uploaded 2c1z3zfvrj.parquet to exp-data-parquet
# upload: data/rmnbxt8dj1.parquet to s3://exp-data-parquet/rmnbxt8dj1.parquet
#
# Successfully uploaded rmnbxt8dj1.parquet to exp-data-parquet
# upload: data/bikk7gl5to.parquet to s3://exp-data-parquet/bikk7gl5to.parquet
#
# Successfully uploaded bikk7gl5to.parquet to exp-data-parquet
# upload: data/mpdik63hsc.parquet to s3://exp-data-parquet/mpdik63hsc.parquet
#
# Successfully uploaded mpdik63hsc.parquet to exp-data-parquet
# upload: data/j1yjdct57m.parquet to s3://exp-data-parquet/j1yjdct57m.parquet
#
# Successfully uploaded j1yjdct57m.parquet to exp-data-parquet
# upload: data/ypirj6oxha.parquet to s3://exp-data-parquet/ypirj6oxha.parquet
#
# Successfully uploaded ypirj6oxha.parquet to exp-data-parquet
# upload: data/cagsv7dnjx.parquet to s3://exp-data-parquet/cagsv7dnjx.parquet
#
# Successfully uploaded cagsv7dnjx.parquet to exp-data-parquet
# upload: data/lhpclmm1zk.parquet to s3://exp-data-parquet/lhpclmm1zk.parquet
#
# Successfully uploaded lhpclmm1zk.parquet to exp-data-parquet
# upload: data/rqqnpjq57k.parquet to s3://exp-data-parquet/rqqnpjq57k.parquet
#
# Successfully uploaded rqqnpjq57k.parquet to exp-data-parquet
# upload: data/y3afu9b3c7.parquet to s3://exp-data-parquet/y3afu9b3c7.parquet
#
# Successfully uploaded y3afu9b3c7.parquet to exp-data-parquet
# upload: data/u61oxdvxxa.parquet to s3://exp-data-parquet/u61oxdvxxa.parquet
#
# Successfully uploaded u61oxdvxxa.parquet to exp-data-parquet
# upload: data/18um8nliha.parquet to s3://exp-data-parquet/18um8nliha.parquet
#
# Successfully uploaded 18um8nliha.parquet to exp-data-parquet
# upload: data/487paxn911.parquet to s3://exp-data-parquet/487paxn911.parquet
#
# Successfully uploaded 487paxn911.parquet to exp-data-parquet
# upload: data/mv2ed24fhk.parquet to s3://exp-data-parquet/mv2ed24fhk.parquet
#
# Successfully uploaded mv2ed24fhk.parquet to exp-data-parquet
# upload: data/swwe2mesnz.parquet to s3://exp-data-parquet/swwe2mesnz.parquet
#
# Successfully uploaded swwe2mesnz.parquet to exp-data-parquet
# upload: data/pplfgrem8l.parquet to s3://exp-data-parquet/pplfgrem8l.parquet
#
# Successfully uploaded pplfgrem8l.parquet to exp-data-parquet
# upload: data/c89wl02z7b.parquet to s3://exp-data-parquet/c89wl02z7b.parquet
#
# Successfully uploaded c89wl02z7b.parquet to exp-data-parquet
# upload: data/nhuzemeoqj.parquet to s3://exp-data-parquet/nhuzemeoqj.parquet
#
# Successfully uploaded nhuzemeoqj.parquet to exp-data-parquet
# upload: data/3eu43sem6r.parquet to s3://exp-data-parquet/3eu43sem6r.parquet
#
# Successfully uploaded 3eu43sem6r.parquet to exp-data-parquet
# upload: data/c0hvhzqst6.parquet to s3://exp-data-parquet/c0hvhzqst6.parquet
#
# Successfully uploaded c0hvhzqst6.parquet to exp-data-parquet
# upload: data/u1wez6wevt.parquet to s3://exp-data-parquet/u1wez6wevt.parquet
#
# Successfully uploaded u1wez6wevt.parquet to exp-data-parquet
# upload: data/b1jbr17q24.parquet to s3://exp-data-parquet/b1jbr17q24.parquet
#
# Successfully uploaded b1jbr17q24.parquet to exp-data-parquet
# upload: data/ubjyf9wk32.parquet to s3://exp-data-parquet/ubjyf9wk32.parquet
#
# Successfully uploaded ubjyf9wk32.parquet to exp-data-parquet
# upload: data/g7wqr9ldbs.parquet to s3://exp-data-parquet/g7wqr9ldbs.parquet
#
# Successfully uploaded g7wqr9ldbs.parquet to exp-data-parquet
# upload: data/dfntl2f6il.parquet to s3://exp-data-parquet/dfntl2f6il.parquet
#
# Successfully uploaded dfntl2f6il.parquet to exp-data-parquet
# upload: data/hm4t32ry75.parquet to s3://exp-data-parquet/hm4t32ry75.parquet
#
# Successfully uploaded hm4t32ry75.parquet to exp-data-parquet
# upload: data/xjy8mcuhhb.parquet to s3://exp-data-parquet/xjy8mcuhhb.parquet
#
# Successfully uploaded xjy8mcuhhb.parquet to exp-data-parquet
# upload: data/xnj72z7blq.parquet to s3://exp-data-parquet/xnj72z7blq.parquet
#
# Successfully uploaded xnj72z7blq.parquet to exp-data-parquet
# upload: data/7f8gvj6hhc.parquet to s3://exp-data-parquet/7f8gvj6hhc.parquet
#
# Successfully uploaded 7f8gvj6hhc.parquet to exp-data-parquet
# upload: data/cxu7luypuf.parquet to s3://exp-data-parquet/cxu7luypuf.parquet
#
# Successfully uploaded cxu7luypuf.parquet to exp-data-parquet
# upload: data/9im2aqhs54.parquet to s3://exp-data-parquet/9im2aqhs54.parquet
#
# Successfully uploaded 9im2aqhs54.parquet to exp-data-parquet
# upload: data/0z710d02cc.parquet to s3://exp-data-parquet/0z710d02cc.parquet
#
# Successfully uploaded 0z710d02cc.parquet to exp-data-parquet
# upload: data/z7w23a7yv2.parquet to s3://exp-data-parquet/z7w23a7yv2.parquet
#
# Successfully uploaded z7w23a7yv2.parquet to exp-data-parquet
# upload: data/6jpcr837v4.parquet to s3://exp-data-parquet/6jpcr837v4.parquet
#
# Successfully uploaded 6jpcr837v4.parquet to exp-data-parquet
# upload: data/9j280943kj.parquet to s3://exp-data-parquet/9j280943kj.parquet
#
# Successfully uploaded 9j280943kj.parquet to exp-data-parquet
# upload: data/atlrttbcvo.parquet to s3://exp-data-parquet/atlrttbcvo.parquet
#
# Successfully uploaded atlrttbcvo.parquet to exp-data-parquet
# upload: data/bu0g3hrz1n.parquet to s3://exp-data-parquet/bu0g3hrz1n.parquet
#
# Successfully uploaded bu0g3hrz1n.parquet to exp-data-parquet
# upload: data/t6wa7h96dz.parquet to s3://exp-data-parquet/t6wa7h96dz.parquet
#
# Successfully uploaded t6wa7h96dz.parquet to exp-data-parquet
# upload: data/h7i1gd26hd.parquet to s3://exp-data-parquet/h7i1gd26hd.parquet
#
# Successfully uploaded h7i1gd26hd.parquet to exp-data-parquet
# upload: data/u340jzzepm.parquet to s3://exp-data-parquet/u340jzzepm.parquet
#
# Successfully uploaded u340jzzepm.parquet to exp-data-parquet
# upload: data/h8a1ma0rl9.parquet to s3://exp-data-parquet/h8a1ma0rl9.parquet
#
# Successfully uploaded h8a1ma0rl9.parquet to exp-data-parquet
# upload: data/5zzfim1vwr.parquet to s3://exp-data-parquet/5zzfim1vwr.parquet
#
# Successfully uploaded 5zzfim1vwr.parquet to exp-data-parquet
# upload: data/j167ejapf8.parquet to s3://exp-data-parquet/j167ejapf8.parquet
#
# Successfully uploaded j167ejapf8.parquet to exp-data-parquet
# upload: data/e53f8gn9gb.parquet to s3://exp-data-parquet/e53f8gn9gb.parquet
#
# Successfully uploaded e53f8gn9gb.parquet to exp-data-parquet
# upload: data/5gx7uw6y1m.parquet to s3://exp-data-parquet/5gx7uw6y1m.parquet
#
# Successfully uploaded 5gx7uw6y1m.parquet to exp-data-parquet
# upload: data/8qd3im21m6.parquet to s3://exp-data-parquet/8qd3im21m6.parquet
#
# Successfully uploaded 8qd3im21m6.parquet to exp-data-parquet
# upload: data/3xet56l298.parquet to s3://exp-data-parquet/3xet56l298.parquet
#
# Successfully uploaded 3xet56l298.parquet to exp-data-parquet
# upload: data/0jiwb7eyeq.parquet to s3://exp-data-parquet/0jiwb7eyeq.parquet
#
# Successfully uploaded 0jiwb7eyeq.parquet to exp-data-parquet
# upload: data/znbmjtjjk5.parquet to s3://exp-data-parquet/znbmjtjjk5.parquet
#
# Successfully uploaded znbmjtjjk5.parquet to exp-data-parquet
# upload: data/gf8igyszdt.parquet to s3://exp-data-parquet/gf8igyszdt.parquet
#
# Successfully uploaded gf8igyszdt.parquet to exp-data-parquet
# upload: data/l27x4ll7nz.parquet to s3://exp-data-parquet/l27x4ll7nz.parquet
#
# Successfully uploaded l27x4ll7nz.parquet to exp-data-parquet
# upload: data/0tff6mmdws.parquet to s3://exp-data-parquet/0tff6mmdws.parquet
#
# Successfully uploaded 0tff6mmdws.parquet to exp-data-parquet
# upload: data/07e9dl4p4m.parquet to s3://exp-data-parquet/07e9dl4p4m.parquet
#
# Successfully uploaded 07e9dl4p4m.parquet to exp-data-parquet
# upload: data/erygo2yccv.parquet to s3://exp-data-parquet/erygo2yccv.parquet
#
# Successfully uploaded erygo2yccv.parquet to exp-data-parquet
# upload: data/f6ndsmixox.parquet to s3://exp-data-parquet/f6ndsmixox.parquet
#
# Successfully uploaded f6ndsmixox.parquet to exp-data-parquet
# upload: data/yikwj3v8d4.parquet to s3://exp-data-parquet/yikwj3v8d4.parquet
#
# Successfully uploaded yikwj3v8d4.parquet to exp-data-parquet
# upload: data/j53uaccmix.parquet to s3://exp-data-parquet/j53uaccmix.parquet
#
# Successfully uploaded j53uaccmix.parquet to exp-data-parquet
# upload: data/3gnt8z97ub.parquet to s3://exp-data-parquet/3gnt8z97ub.parquet
#
# Successfully uploaded 3gnt8z97ub.parquet to exp-data-parquet
# upload: data/pp4epyi4br.parquet to s3://exp-data-parquet/pp4epyi4br.parquet
#
# Successfully uploaded pp4epyi4br.parquet to exp-data-parquet
# upload: data/3exkl8jxmf.parquet to s3://exp-data-parquet/3exkl8jxmf.parquet
#
# Successfully uploaded 3exkl8jxmf.parquet to exp-data-parquet
# upload: data/uqv2hel11s.parquet to s3://exp-data-parquet/uqv2hel11s.parquet
#
# Successfully uploaded uqv2hel11s.parquet to exp-data-parquet
# upload: data/bmu4vi64yj.parquet to s3://exp-data-parquet/bmu4vi64yj.parquet
#
# Successfully uploaded bmu4vi64yj.parquet to exp-data-parquet
# upload: data/jc6h86jmxo.parquet to s3://exp-data-parquet/jc6h86jmxo.parquet
#
# Successfully uploaded jc6h86jmxo.parquet to exp-data-parquet
# upload: data/wiotnlup7t.parquet to s3://exp-data-parquet/wiotnlup7t.parquet
#
# Successfully uploaded wiotnlup7t.parquet to exp-data-parquet
# upload: data/711o35o9p4.parquet to s3://exp-data-parquet/711o35o9p4.parquet
#
# Successfully uploaded 711o35o9p4.parquet to exp-data-parquet
# upload: data/ac33uq5yqh.parquet to s3://exp-data-parquet/ac33uq5yqh.parquet
#
# Successfully uploaded ac33uq5yqh.parquet to exp-data-parquet
# upload: data/sarluoizuz.parquet to s3://exp-data-parquet/sarluoizuz.parquet
#
# Successfully uploaded sarluoizuz.parquet to exp-data-parquet
# upload: data/fdwr381tk3.parquet to s3://exp-data-parquet/fdwr381tk3.parquet
#
# Successfully uploaded fdwr381tk3.parquet to exp-data-parquet
# upload: data/64uy9byg3i.parquet to s3://exp-data-parquet/64uy9byg3i.parquet
#
# Successfully uploaded 64uy9byg3i.parquet to exp-data-parquet
# upload: data/1hscz1e9gu.parquet to s3://exp-data-parquet/1hscz1e9gu.parquet
#
# Successfully uploaded 1hscz1e9gu.parquet to exp-data-parquet
# upload: data/nyt4zdweyr.parquet to s3://exp-data-parquet/nyt4zdweyr.parquet
#
# Successfully uploaded nyt4zdweyr.parquet to exp-data-parquet
# upload: data/xuxqf72hqq.parquet to s3://exp-data-parquet/xuxqf72hqq.parquet
#
# Successfully uploaded xuxqf72hqq.parquet to exp-data-parquet
# upload: data/kcs97aykya.parquet to s3://exp-data-parquet/kcs97aykya.parquet
#
# Successfully uploaded kcs97aykya.parquet to exp-data-parquet
# upload: data/m8hdba3nfe.parquet to s3://exp-data-parquet/m8hdba3nfe.parquet
#
# Successfully uploaded m8hdba3nfe.parquet to exp-data-parquet
# upload: data/i517p0qqoy.parquet to s3://exp-data-parquet/i517p0qqoy.parquet
#
# Successfully uploaded i517p0qqoy.parquet to exp-data-parquet
# upload: data/5gq2fahesc.parquet to s3://exp-data-parquet/5gq2fahesc.parquet
#
# Successfully uploaded 5gq2fahesc.parquet to exp-data-parquet
# upload: data/fs71rtixez.parquet to s3://exp-data-parquet/fs71rtixez.parquet
#
# Successfully uploaded fs71rtixez.parquet to exp-data-parquet
# upload: data/3ws86w85le.parquet to s3://exp-data-parquet/3ws86w85le.parquet
#
# Successfully uploaded 3ws86w85le.parquet to exp-data-parquet
# upload: data/zjcb6khvz4.parquet to s3://exp-data-parquet/zjcb6khvz4.parquet
#
# Successfully uploaded zjcb6khvz4.parquet to exp-data-parquet
# upload: data/xtalwhawgt.parquet to s3://exp-data-parquet/xtalwhawgt.parquet
#
# Successfully uploaded xtalwhawgt.parquet to exp-data-parquet
# upload: data/ila8f5ioay.parquet to s3://exp-data-parquet/ila8f5ioay.parquet
#
# Successfully uploaded ila8f5ioay.parquet to exp-data-parquet
# upload: data/g3gsq2zk20.parquet to s3://exp-data-parquet/g3gsq2zk20.parquet
#
# Successfully uploaded g3gsq2zk20.parquet to exp-data-parquet
# upload: data/ydnd8htnci.parquet to s3://exp-data-parquet/ydnd8htnci.parquet
#
# Successfully uploaded ydnd8htnci.parquet to exp-data-parquet
# upload: data/7ckrljnwo3.parquet to s3://exp-data-parquet/7ckrljnwo3.parquet
#
# Successfully uploaded 7ckrljnwo3.parquet to exp-data-parquet
# upload: data/iozs39l9fl.parquet to s3://exp-data-parquet/iozs39l9fl.parquet
#
# Successfully uploaded iozs39l9fl.parquet to exp-data-parquet
# upload: data/6u22yscwh1.parquet to s3://exp-data-parquet/6u22yscwh1.parquet
#
# Successfully uploaded 6u22yscwh1.parquet to exp-data-parquet
# upload: data/g9kthgn94e.parquet to s3://exp-data-parquet/g9kthgn94e.parquet
#
# Successfully uploaded g9kthgn94e.parquet to exp-data-parquet
# upload: data/iq4bjztgb7.parquet to s3://exp-data-parquet/iq4bjztgb7.parquet
#
# Successfully uploaded iq4bjztgb7.parquet to exp-data-parquet
# upload: data/xslr5c3mmi.parquet to s3://exp-data-parquet/xslr5c3mmi.parquet
#
# Successfully uploaded xslr5c3mmi.parquet to exp-data-parquet
# upload: data/2ue4j4z15b.parquet to s3://exp-data-parquet/2ue4j4z15b.parquet
#
# Successfully uploaded 2ue4j4z15b.parquet to exp-data-parquet
