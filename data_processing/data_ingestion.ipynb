# %%
import boto3
import pandas as pd
import io

s3 = boto3.client('s3')

def calculate_vviq_score(bucket_name, file_key):
    # Download the file from S3
    response = s3.get_object(Bucket=bucket_name, Key=file_key)
    file_content = response['Body'].read()
    
    # Read the Parquet content into a DataFrame
    df = pd.read_parquet(io.BytesIO(file_content))
    
    # Calculate the VVIQ_Score
    score_columns = [f'VVIQ_Q{i}' for i in range(1, 17)]
    df['VVIQ_Score'] = df[score_columns].sum(axis=1)
    
    # Save the modified DataFrame back to Parquet
    scored_file_content = io.BytesIO()
    df.to_parquet(scored_file_content, index=False)
    scored_file_content.seek(0)
    
    # Define the new file name with "_scored" suffix
    new_file_key = file_key.replace('.parquet', '_scored.parquet')
    
    # Upload the new file to S3
    s3.put_object(Bucket=bucket_name, Key=new_file_key, Body=scored_file_content.getvalue())
    
    # Delete the original file from S3
    s3.delete_object(Bucket=bucket_name, Key=file_key)
    
    return f'Successfully processed and deleted {file_key}'

# %%
import boto3
import json

s3 = boto3.client('s3')

def filter_and_distribute(bucket_name, max_workers):
    # List all objects in the bucket
    response = s3.list_objects_v2(Bucket=bucket_name)
    files_to_process = [obj['Key'] for obj in response.get('Contents', []) if not obj['Key'].endswith('_scored.parquet')]
    
    # Divide the files into batches
    batches = [files_to_process[i:i + max_workers] for i in range(0, len(files_to_process), max_workers)]
    
    return batches

# %%
bucket_name = 'exp-data-parquet'
max_workers = 10

# Filter and distribute tasks
batches = filter_and_distribute(bucket_name, max_workers)

# Process each batch
for batch in batches:
    for file_key in batch:
        result = calculate_vviq_score(bucket_name, file_key)
        print(result)
# Out:
# Successfully processed and deleted 07e9dl4p4m.parquet
# Successfully processed and deleted 0ew2g7jfla.parquet
# Successfully processed and deleted 0jiwb7eyeq.parquet
# Successfully processed and deleted 0qa175qzmn.parquet
# Successfully processed and deleted 0tff6mmdws.parquet
# Successfully processed and deleted 0yofabs7se.parquet
# Successfully processed and deleted 0z710d02cc.parquet
# Successfully processed and deleted 18um8nliha.parquet
# Successfully processed and deleted 19wspycaqb.parquet
# Successfully processed and deleted 1czlbmtpxs.parquet
# Successfully processed and deleted 1hscz1e9gu.parquet
# Successfully processed and deleted 1i4dgd97m3.parquet
# Successfully processed and deleted 2amk5u3cgd.parquet
# Successfully processed and deleted 2c1z3zfvrj.parquet
# Successfully processed and deleted 2gcy5cm42i.parquet
# Successfully processed and deleted 2jth6vvh0d.parquet
# Successfully processed and deleted 2syoniq5tq.parquet
# Successfully processed and deleted 2tmd1xetkv.parquet
# Successfully processed and deleted 2ue4j4z15b.parquet
# Successfully processed and deleted 2z8cq3s5rd.parquet
# Successfully processed and deleted 38ml5hf0dx.parquet
# Successfully processed and deleted 396vvsn8hn.parquet
# Successfully processed and deleted 3e32vhjzy1.parquet
# Successfully processed and deleted 3eu43sem6r.parquet
# Successfully processed and deleted 3exkl8jxmf.parquet
# Successfully processed and deleted 3gnt8z97ub.parquet
# Successfully processed and deleted 3mvrbcwto0.parquet
# Successfully processed and deleted 3r2l39udlp.parquet
# Successfully processed and deleted 3smyws11s4.parquet
# Successfully processed and deleted 3ws86w85le.parquet
# Successfully processed and deleted 3wx2etrpt6.parquet
# Successfully processed and deleted 3x1ri3r8kg.parquet
# Successfully processed and deleted 3xet56l298.parquet
# Successfully processed and deleted 3xonogz2k9.parquet
# Successfully processed and deleted 3y8d6aejaj.parquet
# Successfully processed and deleted 487paxn911.parquet
# Successfully processed and deleted 48mq5t4v6e.parquet
# Successfully processed and deleted 4auxgl5oja.parquet
# Successfully processed and deleted 4enptdoyoa.parquet
# Successfully processed and deleted 4l8eow9pc5.parquet
# Successfully processed and deleted 4nar8btra5.parquet
# Successfully processed and deleted 4o5opcpx2b.parquet
# Successfully processed and deleted 4q052hx31s.parquet
# Successfully processed and deleted 53yt5qrkcw.parquet
# Successfully processed and deleted 5gq2fahesc.parquet
# Successfully processed and deleted 5gx7uw6y1m.parquet
# Successfully processed and deleted 5qnht75xjy.parquet
# Successfully processed and deleted 5zzfim1vwr.parquet
# Successfully processed and deleted 64uy9byg3i.parquet
# Successfully processed and deleted 6acj8jzbwd.parquet
# Successfully processed and deleted 6i01pra377.parquet
# Successfully processed and deleted 6j7tb8t04r.parquet
# Successfully processed and deleted 6jpcr837v4.parquet
# Successfully processed and deleted 6o8t8q4b9j.parquet
# Successfully processed and deleted 6u22yscwh1.parquet
# Successfully processed and deleted 70z5w73hrx.parquet
# Successfully processed and deleted 711o35o9p4.parquet
# Successfully processed and deleted 726tb97mzg.parquet
# Successfully processed and deleted 7ckrljnwo3.parquet
# Successfully processed and deleted 7dvv3ss6ny.parquet
# Successfully processed and deleted 7eylttq5nq.parquet
# Successfully processed and deleted 7f8gvj6hhc.parquet
# Successfully processed and deleted 7p5niy1gtu.parquet
# Successfully processed and deleted 7rd31d5vci.parquet
# Successfully processed and deleted 7tx613qz6g.parquet
# Successfully processed and deleted 7vum8xytf9.parquet
# Successfully processed and deleted 7xyd3qe8a1.parquet
# Successfully processed and deleted 7yd3rs0y65.parquet
# Successfully processed and deleted 8bb32fwvkx.parquet
# Successfully processed and deleted 8l78evaync.parquet
# Successfully processed and deleted 8mh4ao4thm.parquet
# Successfully processed and deleted 8ogk04msmd.parquet
# Successfully processed and deleted 8qd3im21m6.parquet
# Successfully processed and deleted 8zzuwobjlr.parquet
# Successfully processed and deleted 95e24ic0qc.parquet
# Successfully processed and deleted 9im2aqhs54.parquet
# Successfully processed and deleted 9j280943kj.parquet
# Successfully processed and deleted 9ktaiva0di.parquet
# Successfully processed and deleted 9pav9eseke.parquet
# Successfully processed and deleted 9siqeq886g.parquet
# Successfully processed and deleted 9tmhqldp29.parquet
# Successfully processed and deleted 9x8r3yxn9y.parquet
# Successfully processed and deleted 9zktphvymz.parquet
# Successfully processed and deleted a9buszoz26.parquet
# Successfully processed and deleted ac33uq5yqh.parquet
# Successfully processed and deleted afdd56ach1.parquet
# Successfully processed and deleted amxepijc5p.parquet
# Successfully processed and deleted aqj21awgbf.parquet
# Successfully processed and deleted atlrttbcvo.parquet
# Successfully processed and deleted ay3j8it15q.parquet
# Successfully processed and deleted b0iokv2vul.parquet
# Successfully processed and deleted b1jbr17q24.parquet
# Successfully processed and deleted b55hj2z1hq.parquet
# Successfully processed and deleted bf1ca2yj92.parquet
# Successfully processed and deleted bikk7gl5to.parquet
# Successfully processed and deleted bmu4vi64yj.parquet
# Successfully processed and deleted bqmqo2d5ps.parquet
# Successfully processed and deleted bu0g3hrz1n.parquet
# Successfully processed and deleted c0hvhzqst6.parquet
# Successfully processed and deleted c4xjudnq2z.parquet
# Successfully processed and deleted c89wl02z7b.parquet
# Successfully processed and deleted cagsv7dnjx.parquet
# Successfully processed and deleted climvbet61.parquet
# Successfully processed and deleted cr3tl5f9tz.parquet
# Successfully processed and deleted crgj29qjtb.parquet
# Successfully processed and deleted cxu7luypuf.parquet
# Successfully processed and deleted d0j667ohs4.parquet
# Successfully processed and deleted d2vlphhmey.parquet
# Successfully processed and deleted d8bhwk90je.parquet
# Successfully processed and deleted dfntl2f6il.parquet
# Successfully processed and deleted dgwn46ny48.parquet
# Successfully processed and deleted dluorwikdk.parquet
# Successfully processed and deleted dsan87l3jf.parquet
# Successfully processed and deleted dw0hrzr11b.parquet
# Successfully processed and deleted dwlgyfg2jl.parquet
# Successfully processed and deleted dz8zw51fup.parquet
# Successfully processed and deleted e53f8gn9gb.parquet
# Successfully processed and deleted eecxg1q25q.parquet
# Successfully processed and deleted eks788d6fh.parquet
# Successfully processed and deleted eo0z8ykzdg.parquet
# Successfully processed and deleted erwvftxrc5.parquet
# Successfully processed and deleted erygo2yccv.parquet
# Successfully processed and deleted es6f4x2jxi.parquet
# Successfully processed and deleted etp2y35mu2.parquet
# Successfully processed and deleted f69i2ei450.parquet
# Successfully processed and deleted f6ndsmixox.parquet
# Successfully processed and deleted fdwr381tk3.parquet
# Successfully processed and deleted fdzgdgbx1e.parquet
# Successfully processed and deleted fezqwgrthi.parquet
# Successfully processed and deleted fs71rtixez.parquet
# Successfully processed and deleted fskwwjke39.parquet
# Successfully processed and deleted fuqip725e4.parquet
# Successfully processed and deleted g3gsq2zk20.parquet
# Successfully processed and deleted g4tlunly5c.parquet
# Successfully processed and deleted g7wqr9ldbs.parquet
# Successfully processed and deleted g9kthgn94e.parquet
# Successfully processed and deleted gb1vz651g8.parquet
# Successfully processed and deleted gf8igyszdt.parquet
# Successfully processed and deleted gl58dodp72.parquet
# Successfully processed and deleted gorq7e4j0w.parquet
# Successfully processed and deleted gqy3mtffco.parquet
# Successfully processed and deleted gu4zap65kq.parquet
# Successfully processed and deleted h3pusayhz6.parquet
# Successfully processed and deleted h7i1gd26hd.parquet
# Successfully processed and deleted h8a1ma0rl9.parquet
# Successfully processed and deleted h9e681stj9.parquet
# Successfully processed and deleted hate3kpzc8.parquet
# Successfully processed and deleted hekvj9y8yl.parquet
# Successfully processed and deleted hf3edxpl7h.parquet
# Successfully processed and deleted hhxi4jxok2.parquet
# Successfully processed and deleted hifdltf66y.parquet
# Successfully processed and deleted hm4t32ry75.parquet
# Successfully processed and deleted hr14bux9rs.parquet
# Successfully processed and deleted htrv2g932g.parquet
# Successfully processed and deleted hz3m1e0tac.parquet
# Successfully processed and deleted i29ui2ssd9.parquet
# Successfully processed and deleted i517p0qqoy.parquet
# Successfully processed and deleted i6zk0q6jaf.parquet
# Successfully processed and deleted ik87zz580g.parquet
# Successfully processed and deleted ikhs8jmee7.parquet
# Successfully processed and deleted ila8f5ioay.parquet
# Successfully processed and deleted ilmelxb2gl.parquet
# Successfully processed and deleted in0ygjwyzi.parquet
# Successfully processed and deleted in2b8bz2vl.parquet
# Successfully processed and deleted insasj8at3.parquet
# Successfully processed and deleted iozs39l9fl.parquet
# Successfully processed and deleted iq4bjztgb7.parquet
# Successfully processed and deleted j167ejapf8.parquet
# Successfully processed and deleted j1yjdct57m.parquet
# Successfully processed and deleted j4s1u9uruu.parquet
# Successfully processed and deleted j53uaccmix.parquet
# Successfully processed and deleted j815jyvnd6.parquet
# Successfully processed and deleted j9vb4bqakq.parquet
# Successfully processed and deleted jc6h86jmxo.parquet
# Successfully processed and deleted jfied1il87.parquet
# Successfully processed and deleted jkvyvd4lj2.parquet
# Successfully processed and deleted jp3vh0t1cu.parquet
# Successfully processed and deleted jqe440xbl7.parquet
# Successfully processed and deleted jwbrexteac.parquet
# Successfully processed and deleted k15thshzyp.parquet
# Successfully processed and deleted k8fgjcvusi.parquet
# Successfully processed and deleted kcs97aykya.parquet
# Successfully processed and deleted l27x4ll7nz.parquet
# Successfully processed and deleted la2jrbcf0o.parquet
# Successfully processed and deleted lb9wq6jv53.parquet
# Successfully processed and deleted lbxo0hq58d.parquet
# Successfully processed and deleted lg1b3ebgy4.parquet
# Successfully processed and deleted lhpclmm1zk.parquet
# Successfully processed and deleted lno53dakx5.parquet
# Successfully processed and deleted lo56n48t4q.parquet
# Successfully processed and deleted lsmca2pd74.parquet
# Successfully processed and deleted lzo16sfwcx.parquet
# Successfully processed and deleted lzo82q157d.parquet
# Successfully processed and deleted m19wi9bhda.parquet
# Successfully processed and deleted m6yc6ebvi1.parquet
# Successfully processed and deleted m8hdba3nfe.parquet
# Successfully processed and deleted m998ytl1uj.parquet
# Successfully processed and deleted mpdik63hsc.parquet
# Successfully processed and deleted muzom0tm6x.parquet
# Successfully processed and deleted mv2ed24fhk.parquet
# Successfully processed and deleted n7vgh3fbpy.parquet
# Successfully processed and deleted n80t3vh4qv.parquet
# Successfully processed and deleted nhuzemeoqj.parquet
# Successfully processed and deleted nx6of9jlrq.parquet
# Successfully processed and deleted nyt4zdweyr.parquet
# Successfully processed and deleted opgab563e6.parquet
# Successfully processed and deleted ov2dk70va7.parquet
# Successfully processed and deleted oyreas5tv7.parquet
# Successfully processed and deleted p2vtsbn0ms.parquet
# Successfully processed and deleted p7nfmpq0a8.parquet
# Successfully processed and deleted partt95v64.parquet
# Successfully processed and deleted pg6u203631.parquet
# Successfully processed and deleted phge8enp71.parquet
# Successfully processed and deleted pog8go5lp7.parquet
# Successfully processed and deleted poqnjid6ch.parquet
# Successfully processed and deleted pp4epyi4br.parquet
# Successfully processed and deleted pplfgrem8l.parquet
# Successfully processed and deleted pxguox9yzy.parquet
# Successfully processed and deleted pzqqmhddkd.parquet
# Successfully processed and deleted qbvnv9jzoo.parquet
# Successfully processed and deleted qdfqmdmww4.parquet
# Successfully processed and deleted qmbqtfzftn.parquet
# Successfully processed and deleted qril0pv7t1.parquet
# Successfully processed and deleted qtb50sbqwx.parquet
# Successfully processed and deleted r0v6p2gfz5.parquet
# Successfully processed and deleted r4jc84o0qz.parquet
# Successfully processed and deleted r7m67f8t6x.parquet
# Successfully processed and deleted rdw4whjl2k.parquet
# Successfully processed and deleted rfthh6njkx.parquet
# Successfully processed and deleted rj2mjtih4z.parquet
# Successfully processed and deleted rlanxfd9h8.parquet
# Successfully processed and deleted rmnbxt8dj1.parquet
# Successfully processed and deleted rqqnpjq57k.parquet
# Successfully processed and deleted ryjoedcwup.parquet
# Successfully processed and deleted s0thu77s6g.parquet
# Successfully processed and deleted sarluoizuz.parquet
# Successfully processed and deleted sbu3uy8wre.parquet
# Successfully processed and deleted sq5n5jbqjl.parquet
# Successfully processed and deleted sqjex4h3lp.parquet
# Successfully processed and deleted ssb27wwroc.parquet
# Successfully processed and deleted stpgk0v04r.parquet
# Successfully processed and deleted swwe2mesnz.parquet
# Successfully processed and deleted sxrl60bne2.parquet
# Successfully processed and deleted sz5vgarrvj.parquet
# Successfully processed and deleted szi4hn9mav.parquet
# Successfully processed and deleted t51zn0n1na.parquet
# Successfully processed and deleted t5o9igg105.parquet
# Successfully processed and deleted t6wa7h96dz.parquet
# Successfully processed and deleted trfjn5qisb.parquet
# Successfully processed and deleted tsm2z2ncmn.parquet
# Successfully processed and deleted tsqfvmlo59.parquet
# Successfully processed and deleted tv7kpw8o7w.parquet
# Successfully processed and deleted u1wez6wevt.parquet
# Successfully processed and deleted u340jzzepm.parquet
# Successfully processed and deleted u61oxdvxxa.parquet
# Successfully processed and deleted u83cyyzh4k.parquet
# Successfully processed and deleted ubjyf9wk32.parquet
# Successfully processed and deleted ul1ixkkn2i.parquet
# Successfully processed and deleted uqv2hel11s.parquet
# Successfully processed and deleted uxa80d98x3.parquet
# Successfully processed and deleted uykgbkdshi.parquet
# Successfully processed and deleted v11jssqgrj.parquet
# Successfully processed and deleted v3ktzqofo9.parquet
# Successfully processed and deleted v3qjitfvni.parquet
# Successfully processed and deleted v6ozawvmc6.parquet
# Successfully processed and deleted v9kgvi16a3.parquet
# Successfully processed and deleted vb724j1hkh.parquet
# Successfully processed and deleted vcixp5fz70.parquet
# Successfully processed and deleted vmid6f45oc.parquet
# Successfully processed and deleted vq9o7uj8ju.parquet
# Successfully processed and deleted wbmvr4ccm2.parquet
# Successfully processed and deleted wgk18ldtmr.parquet
# Successfully processed and deleted wi1pqcssne.parquet
# Successfully processed and deleted wiotnlup7t.parquet
# Successfully processed and deleted wpd6opaa1m.parquet
# Successfully processed and deleted wtr4rp8j5p.parquet
# Successfully processed and deleted x3fmbwhqm6.parquet
# Successfully processed and deleted x9e2syyeri.parquet
# Successfully processed and deleted xbnxqe5pne.parquet
# Successfully processed and deleted xdq687wdte.parquet
# Successfully processed and deleted xhctf6010h.parquet
# Successfully processed and deleted xjy8mcuhhb.parquet
# Successfully processed and deleted xnj72z7blq.parquet
# Successfully processed and deleted xntinjn90u.parquet
# Successfully processed and deleted xrvunj7ivi.parquet
# Successfully processed and deleted xslr5c3mmi.parquet
# Successfully processed and deleted xtalwhawgt.parquet
# Successfully processed and deleted xuxqf72hqq.parquet
# Successfully processed and deleted xzbf0rpqv2.parquet
# Successfully processed and deleted y3afu9b3c7.parquet
# Successfully processed and deleted y4655zphpk.parquet
# Successfully processed and deleted y4yde5w2nw.parquet
# Successfully processed and deleted y7uxaxmbgb.parquet
# Successfully processed and deleted y9esnlx5vp.parquet
# Successfully processed and deleted ydnd8htnci.parquet
# Successfully processed and deleted ygechsi2jr.parquet
# Successfully processed and deleted yi6684t409.parquet
# Successfully processed and deleted yikwj3v8d4.parquet
# Successfully processed and deleted yloq4axryl.parquet
# Successfully processed and deleted ypirj6oxha.parquet
# Successfully processed and deleted ypyzigczm6.parquet
# Successfully processed and deleted yrrdo2idps.parquet
# Successfully processed and deleted z0z4o8x2sp.parquet
# Successfully processed and deleted z5s0rjsm4p.parquet
# Successfully processed and deleted z7eef6qj8u.parquet
# Successfully processed and deleted z7w23a7yv2.parquet
# Successfully processed and deleted zixlh6hbh5.parquet
# Successfully processed and deleted zjcb6khvz4.parquet
# Successfully processed and deleted znbmjtjjk5.parquet
# Successfully processed and deleted zo3ir981th.parquet

# %%
import boto3
import pandas as pd
import os

# Initialize boto3 S3 client
s3 = boto3.client('s3')

# Define buckets and file names
source_bucket = 'exp-data-parquet'
destination_bucket = 'aggregated-exp-data-parquet'
aggregated_file = 'aggregated_exp_data.parquet'

# Define columns to include in the final aggregated file
columns_to_include = [
    'EmailAddress', 'FutureContactConsent', 'Age', 'Sex', 'Ethnicity',
    'Race', 'IdealParticipation', 'AttentionCheckTask', 'VVIQ_Score'
]

# %%
def ensure_bucket_exists(bucket_name):
    try:
        s3.head_bucket(Bucket=bucket_name)
        print(f"Bucket '{bucket_name}' already exists.")
    except:
        s3.create_bucket(Bucket=bucket_name)
        print(f"Bucket '{bucket_name}' created.")

# %%
def check_file_exists(bucket_name, file_key):
    try:
        s3.head_object(Bucket=bucket_name, Key=file_key)
        print(f"File '{file_key}' already exists in bucket '{bucket_name}'.")
        return True
    except:
        print(f"File '{file_key}' does not exist in bucket '{bucket_name}'.")
        return False

def read_parquet_from_s3(bucket_name, file_key):
    obj = s3.get_object(Bucket=bucket_name, Key=file_key)
    return pd.read_parquet(io.BytesIO(obj['Body'].read()))

# %%
def aggregate_and_upload_files():
    ensure_bucket_exists(destination_bucket)
    
    # List objects in the source bucket
    response = s3.list_objects_v2(Bucket=source_bucket)
    files_to_process = [obj['Key'] for obj in response.get('Contents', []) 
                        if obj['Key'].endswith('_scored.parquet') and not obj['Key'].startswith('merged_')]

    aggregated_data = pd.DataFrame(columns=columns_to_include)

    # Process each file
    for file_key in files_to_process:
        df = read_parquet_from_s3(source_bucket, file_key)
        df_filtered = df[columns_to_include]
        aggregated_data = pd.concat([aggregated_data, df_filtered], ignore_index=True)
        
        # Rename and move the processed file
        new_file_key = 'merged_' + file_key
        s3.copy_object(Bucket=source_bucket, CopySource={'Bucket': source_bucket, 'Key': file_key}, Key=new_file_key)
        s3.delete_object(Bucket=source_bucket, Key=file_key)

    # Check if the aggregated file already exists
    if check_file_exists(destination_bucket, aggregated_file):
        existing_data = read_parquet_from_s3(destination_bucket, aggregated_file)
        aggregated_data = pd.concat([existing_data, aggregated_data], ignore_index=True)
    
    # Save the aggregated data to a Parquet file
    aggregated_file_content = io.BytesIO()
    aggregated_data.to_parquet(aggregated_file_content, index=False)
    aggregated_file_content.seek(0)
    
    # Upload the aggregated Parquet file to the destination bucket
    s3.put_object(Bucket=destination_bucket, Key=aggregated_file, Body=aggregated_file_content.getvalue())
    print(f"Aggregated data uploaded to '{destination_bucket}/{aggregated_file}'.")

aggregate_and_upload_files()
# Out:
# Bucket 'aggregated-exp-data-parquet' created.
# File 'aggregated_exp_data.parquet' does not exist in bucket 'aggregated-exp-data-parquet'.
# Aggregated data uploaded to 'aggregated-exp-data-parquet/aggregated_exp_data.parquet'.

# %%
# Verify the aggregated file
if check_file_exists(destination_bucket, aggregated_file):
    print(f"The file '{aggregated_file}' was successfully created or updated in bucket '{destination_bucket}'.")
else:
    print(f"Failed to create or update the file '{aggregated_file}' in bucket '{destination_bucket}'.")
# Out:
# File 'aggregated_exp_data.parquet' already exists in bucket 'aggregated-exp-data-parquet'.
# The file 'aggregated_exp_data.parquet' was successfully created or updated in bucket 'aggregated-exp-data-parquet'.
